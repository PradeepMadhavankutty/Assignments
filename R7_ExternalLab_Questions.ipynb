# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
(trainX, trainY),(testX, testY) = tf.keras.datasets.mnist.load_data()

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
trainY = tf.keras.utils.to_categorical(trainY, num_classes=10)
testY = tf.keras.utils.to_categorical(testY, num_classes=10)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,),input_shape=(28,28,)))
model.add(tf.keras.layers.BatchNormalization())

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
#Hidden layers
model.add(tf.keras.layers.Dense(200, activation='relu', name='Layer_1'))
model.add(tf.keras.layers.Dense(100, activation='relu', name='Layer_2'))

#Dropout layer
model.add(tf.keras.layers.Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax', name='Output'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#Train the model
model.fit(trainX,trainY,          
          validation_data=(testX,testY),
          epochs=30,
          batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 21s 345us/step - loss: 0.2639 - acc: 0.9196 - val_loss: 0.1585 - val_acc: 0.9591
# Epoch 2/30
# 60000/60000 [==============================] - 16s 260us/step - loss: 0.1320 - acc: 0.9603 - val_loss: 0.1403 - val_acc: 0.9667
# Epoch 3/30
# 60000/60000 [==============================] - 15s 250us/step - loss: 0.1006 - acc: 0.9684 - val_loss: 0.1423 - val_acc: 0.9699
# Epoch 4/30
# 60000/60000 [==============================] - 16s 270us/step - loss: 0.0794 - acc: 0.9756 - val_loss: 0.1382 - val_acc: 0.9720
# Epoch 5/30
# 60000/60000 [==============================] - 21s 351us/step - loss: 0.0720 - acc: 0.9765 - val_loss: 0.1402 - val_acc: 0.9699
# Epoch 6/30
# 60000/60000 [==============================] - 17s 289us/step - loss: 0.0631 - acc: 0.9808 - val_loss: 0.1601 - val_acc: 0.9712
# Epoch 7/30
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.0560 - acc: 0.9827 - val_loss: 0.1561 - val_acc: 0.9714
# Epoch 8/30
# 60000/60000 [==============================] - 18s 301us/step - loss: 0.0531 - acc: 0.9836 - val_loss: 0.1390 - val_acc: 0.9745
# Epoch 9/30
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.0468 - acc: 0.9854 - val_loss: 0.1477 - val_acc: 0.9718
# Epoch 10/30
# 60000/60000 [==============================] - 18s 294us/step - loss: 0.0466 - acc: 0.9852 - val_loss: 0.1620 - val_acc: 0.9718- loss: 0.0467 -
# Epoch 11/30
# 60000/60000 [==============================] - 19s 317us/step - loss: 0.0414 - acc: 0.9871 - val_loss: 0.1789 - val_acc: 0.9714
# Epoch 12/30
# 60000/60000 [==============================] - 18s 299us/step - loss: 0.0381 - acc: 0.9875 - val_loss: 0.1656 - val_acc: 0.9722
# Epoch 13/30
# 60000/60000 [==============================] - 16s 268us/step - loss: 0.0356 - acc: 0.9888 - val_loss: 0.1740 - val_acc: 0.9730
# Epoch 14/30
# 60000/60000 [==============================] - 17s 282us/step - loss: 0.0366 - acc: 0.9885 - val_loss: 0.1685 - val_acc: 0.9734
# Epoch 15/30
# 60000/60000 [==============================] - 19s 318us/step - loss: 0.0352 - acc: 0.9894 - val_loss: 0.1764 - val_acc: 0.9724
# Epoch 16/30
# 60000/60000 [==============================] - 16s 270us/step - loss: 0.0293 - acc: 0.9907 - val_loss: 0.1775 - val_acc: 0.9716
# Epoch 17/30
# 60000/60000 [==============================] - 19s 323us/step - loss: 0.0318 - acc: 0.9900 - val_loss: 0.1740 - val_acc: 0.9730
# Epoch 18/30
# 60000/60000 [==============================] - 30s 505us/step - loss: 0.0330 - acc: 0.9905 - val_loss: 0.1899 - val_acc: 0.9726
# Epoch 19/30
# 60000/60000 [==============================] - 19s 320us/step - loss: 0.0304 - acc: 0.9908 - val_loss: 0.2024 - val_acc: 0.9706
# Epoch 20/30
# 60000/60000 [==============================] - 22s 365us/step - loss: 0.0277 - acc: 0.9918 - val_loss: 0.2010 - val_acc: 0.9713
# Epoch 21/30
# 60000/60000 [==============================] - 18s 301us/step - loss: 0.0281 - acc: 0.9915 - val_loss: 0.2119 - val_acc: 0.9708
# Epoch 22/30
# 60000/60000 [==============================] - 17s 288us/step - loss: 0.0293 - acc: 0.9918 - val_loss: 0.2061 - val_acc: 0.9726
# Epoch 23/30
# 60000/60000 [==============================] - 18s 292us/step - loss: 0.0251 - acc: 0.9929 - val_loss: 0.2359 - val_acc: 0.9718
# Epoch 24/30
# 60000/60000 [==============================] - 18s 307us/step - loss: 0.0282 - acc: 0.9916 - val_loss: 0.2140 - val_acc: 0.9709
# Epoch 25/30
# 60000/60000 [==============================] - 22s 363us/step - loss: 0.0255 - acc: 0.9923 - val_loss: 0.2446 - val_acc: 0.9683
# Epoch 26/30
# 60000/60000 [==============================] - 22s 363us/step - loss: 0.0243 - acc: 0.9928 - val_loss: 0.2001 - val_acc: 0.9732
# Epoch 27/30
# 60000/60000 [==============================] - 23s 385us/step - loss: 0.0258 - acc: 0.9926 - val_loss: 0.2035 - val_acc: 0.9727
# Epoch 28/30
# 18432/60000 [========>.....................] - ETA: 18s - loss: 0.0228 - acc: 0.9934 ETA: 17s - loss: 0.0229 - acc: WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104279). Check your callbacks.
# 18464/60000 [========>.....................] - ETA: 19s - loss: 0.0230 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.111797). Check your callbacks.
# 19264/60000 [========>.....................] - ETA: 23s - loss: 0.0228 - acc: 0.9933 ETAWARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.100666). Check your callbacks.
# 19296/60000 [========>.....................] - ETA: 23s - loss: 0.0228 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104139). Check your callbacks.
# 19328/60000 [========>.....................] - ETA: 24s - loss: 0.0228 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104139). Check your callbacks.
# 19392/60000 [========>.....................] - ETA: 24s - loss: 0.0227 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.107783). Check your callbacks.
# 19424/60000 [========>.....................] - ETA: 25s - loss: 0.0227 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.107783). Check your callbacks.
# 19456/60000 [========>.....................] - ETA: 25s - loss: 0.0227 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.123883). Check your callbacks.
# 19488/60000 [========>.....................] - ETA: 26s - loss: 0.0227 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.123883). Check your callbacks.
# 19520/60000 [========>.....................] - ETA: 26s - loss: 0.0226 - acc: 0.9933WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.123883). Check your callbacks.
# 19552/60000 [========>.....................] - ETA: 26s - loss: 0.0226 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.107783). Check your callbacks.
# 19584/60000 [========>.....................] - ETA: 26s - loss: 0.0225 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.105502). Check your callbacks.
# 19616/60000 [========>.....................] - ETA: 27s - loss: 0.0225 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104034). Check your callbacks.
# 19648/60000 [========>.....................] - ETA: 28s - loss: 0.0225 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104034). Check your callbacks.
# 19680/60000 [========>.....................] - ETA: 29s - loss: 0.0224 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.121080). Check your callbacks.
# 19712/60000 [========>.....................] - ETA: 29s - loss: 0.0224 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.121080). Check your callbacks.
# 19744/60000 [========>.....................] - ETA: 30s - loss: 0.0224 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.104034). Check your callbacks.
# 19776/60000 [========>.....................] - ETA: 30s - loss: 0.0223 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.102775). Check your callbacks.
# 19808/60000 [========>.....................] - ETA: 31s - loss: 0.0223 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.112558). Check your callbacks.
# 19840/60000 [========>.....................] - ETA: 32s - loss: 0.0224 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.119998). Check your callbacks.
# 19872/60000 [========>.....................] - ETA: 32s - loss: 0.0224 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.127261). Check your callbacks.
# 19904/60000 [========>.....................] - ETA: 34s - loss: 0.0223 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.154897). Check your callbacks.
# 19936/60000 [========>.....................] - ETA: 35s - loss: 0.0223 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.154897). Check your callbacks.
# 19968/60000 [========>.....................] - ETA: 35s - loss: 0.0223 - acc: 0.9934WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.127261). Check your callbacks.
# 20000/60000 [=========>....................] - ETA: 35s - loss: 0.0222 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.124278). Check your callbacks.
# 20032/60000 [=========>....................] - ETA: 36s - loss: 0.0222 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.116838). Check your callbacks.
# 20064/60000 [=========>....................] - ETA: 36s - loss: 0.0222 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.116838). Check your callbacks.
# 20096/60000 [=========>....................] - ETA: 36s - loss: 0.0222 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.110320). Check your callbacks.
# 20128/60000 [=========>....................] - ETA: 36s - loss: 0.0221 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.110320). Check your callbacks.
# 20160/60000 [=========>....................] - ETA: 37s - loss: 0.0221 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.110320). Check your callbacks.
# 21600/60000 [=========>....................] - ETA: 37s - loss: 0.0219 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.102242). Check your callbacks.
# 21632/60000 [=========>....................] - ETA: 38s - loss: 0.0219 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.105776). Check your callbacks.
# 21664/60000 [=========>....................] - ETA: 38s - loss: 0.0219 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.105776). Check your callbacks.
# 21696/60000 [=========>....................] - ETA: 38s - loss: 0.0218 - acc: 0.9935WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.105776). Check your callbacks.
# 60000/60000 [==============================] - 39s 655us/step - loss: 0.0234 - acc: 0.9929 - val_loss: 0.1809 - val_acc: 0.9749
# Epoch 29/30
# 60000/60000 [==============================] - 29s 485us/step - loss: 0.0218 - acc: 0.9934 - val_loss: 0.2534 - val_acc: 0.9683s - loss: 0.0218 - acc: 0.
# Epoch 30/30
# 60000/60000 [==============================] - 27s 444us/step - loss: 0.0258 - acc: 0.9927 - val_loss: 0.2398 - val_acc: 0.9694

# %% [markdown]
# ## Word Embeddings in Python with Gensim

# %% [markdown]
# In this, you will practice how to train and load word embedding models for natural language processing applications in Python using Gensim.

# %% [markdown]
# 1. How to train your own word2vec word embedding model on text data.
# 2. How to visualize a trained word embedding model using Principal Component Analysis.
# 3. How to load pre-trained word2vec word embedding models.

# %% [markdown]
# ### Run the below two commands to install gensim and the wiki dataset

# %%
# !pip install --upgrade gensim --user

# %%
# !pip install wikipedia --user

# %% [markdown]
# ### Import gensim

# %%
import gensim

# %% [markdown]
# ### Obtain Text

# %% [markdown]
# Import search and page functions from wikipedia module
# search(/key word/): search function takes keyword as argument and gives top 10 article titles matching the given keyword.
#
# page(/title of article/): page function takes page title as argument and gives content in the output.

# %%
## Usage: 

content = []
title = []
i =0 
from wikipedia import search, page
titles = search("Machine Learning")
for i in range(10):
    wikipage = page(titles[i])
    #print (wikipage.titles)
    title.append(wikipage.title)
    content.append(wikipage.content)

# %% [markdown]
# ### Print the top 10 titles for the keyword `Machine Learning`

# %%
import pandas as pd
df = pd.DataFrame()
df['content'] = content
df['Title'] = title

# %%
df.head(10)
# Out:
#                                              content  \
# 0  Machine learning (ML) is the scientific study ...
# 1  Active learning is a special case of machine l...
# 2  Boosting is a machine learning ensemble meta-a...
# 3  Deep learning (also known as deep structured l...
# 4  These datasets are used for machine-learning r...
# 5  In machine learning, support-vector machines (...
# 6  The following outline is provided as an overvi...
# 7  Waikato Environment for Knowledge Analysis (We...
# 8  Adversarial machine learning is a technique em...
# 9  Extreme learning machines are feedforward neur...
#
#                                             Title
# 0                                Machine learning
# 1              Active learning (machine learning)
# 2                     Boosting (machine learning)
# 3                                   Deep learning
# 4  List of datasets for machine learning research
# 5                          Support-vector machine
# 6                     Outline of machine learning
# 7                         Weka (machine learning)
# 8                    Adversarial machine learning
# 9                        Extreme learning machine

# %% [markdown]
# ### Get the content from the first title from the above obtained 10 titles.

# %%
import re, string

def clean_str(string):
  """
  String cleaning before vectorization
  """
  try:    
    string = re.sub(r'^https?:\/\/<>.*[\r\n]*', '', string, flags=re.MULTILINE)
    string = re.sub(r"[^A-Za-z]", " ", string)         
    words = string.strip().lower().split()    
    words = [w for w in words if len(w)>=1]
    return " ".join(words)	
  except:
    return ""

# %%
df['clean_Content'] = df['content'].apply(clean_str)
df.head()
# Out:
#                                              content  \
# 0  Machine learning (ML) is the scientific study ...
# 1  Active learning is a special case of machine l...
# 2  Boosting is a machine learning ensemble meta-a...
# 3  Deep learning (also known as deep structured l...
# 4  These datasets are used for machine-learning r...
#
#                                             Title  \
# 0                                Machine learning
# 1              Active learning (machine learning)
# 2                     Boosting (machine learning)
# 3                                   Deep learning
# 4  List of datasets for machine learning research
#
#                                        clean_Content
# 0  machine learning ml is the scientific study of...
# 1  active learning is a special case of machine l...
# 2  boosting is a machine learning ensemble meta a...
# 3  deep learning also known as deep structured le...
# 4  these datasets are used for machine learning r...

# %% [markdown]
# ### Create a list with name `documents` and append all the words in the 10 pages' content using the above 10 titles.

# %%
#List to hold all words in each review
documents = []

#Iterate over each review
for doc in df['clean_Content']:
    documents.append(doc.split(' '))

print(len(documents))
print(documents[0])
# Out:
# 10
# ['machine', 'learning', 'ml', 'is', 'the', 'scientific', 'study', 'of', 'algorithms', 'and', 'statistical', 'models', 'that', 'computer', 'systems', 'use', 'to', 'effectively', 'perform', 'a', 'specific', 'task', 'without', 'using', 'explicit', 'instructions', 'relying', 'on', 'patterns', 'and', 'inference', 'instead', 'it', 'is', 'seen', 'as', 'a', 'subset', 'of', 'artificial', 'intelligence', 'machine', 'learning', 'algorithms', 'build', 'a', 'mathematical', 'model', 'of', 'sample', 'data', 'known', 'as', 'training', 'data', 'in', 'order', 'to', 'make', 'predictions', 'or', 'decisions', 'without', 'being', 'explicitly', 'programmed', 'to', 'perform', 'the', 'task', 'machine', 'learning', 'algorithms', 'are', 'used', 'in', 'the', 'applications', 'of', 'email', 'filtering', 'detection', 'of', 'network', 'intruders', 'and', 'computer', 'vision', 'where', 'it', 'is', 'infeasible', 'to', 'develop', 'an', 'algorithm', 'of', 'specific', 'instructions', 'for', 'performing', 'the', 'task', 'machine', 'learning', 'is', 'closely', 'related', 'to', 'computational', 'statistics', 'which', 'focuses', 'on', 'making', 'predictions', 'using', 'computers', 'the', 'study', 'of', 'mathematical', 'optimization', 'delivers', 'methods', 'theory', 'and', 'application', 'domains', 'to', 'the', 'field', 'of', 'machine', 'learning', 'data', 'mining', 'is', 'a', 'field', 'of', 'study', 'within', 'machine', 'learning', 'and', 'focuses', 'on', 'exploratory', 'data', 'analysis', 'through', 'unsupervised', 'learning', 'in', 'its', 'application', 'across', 'business', 'problems', 'machine', 'learning', 'is', 'also', 'referred', 'to', 'as', 'predictive', 'analytics', 'overview', 'of', 'machine', 'learning', 'the', 'name', 'machine', 'learning', 'was', 'coined', 'in', 'by', 'arthur', 'samuel', 'tom', 'm', 'mitchell', 'provided', 'a', 'widely', 'quoted', 'more', 'formal', 'definition', 'of', 'the', 'algorithms', 'studied', 'in', 'the', 'machine', 'learning', 'field', 'a', 'computer', 'program', 'is', 'said', 'to', 'learn', 'from', 'experience', 'e', 'with', 'respect', 'to', 'some', 'class', 'of', 'tasks', 't', 'and', 'performance', 'measure', 'p', 'if', 'its', 'performance', 'at', 'tasks', 'in', 't', 'as', 'measured', 'by', 'p', 'improves', 'with', 'experience', 'e', 'this', 'definition', 'of', 'the', 'tasks', 'in', 'which', 'machine', 'learning', 'is', 'concerned', 'offers', 'a', 'fundamentally', 'operational', 'definition', 'rather', 'than', 'defining', 'the', 'field', 'in', 'cognitive', 'terms', 'this', 'follows', 'alan', 'turing', 's', 'proposal', 'in', 'his', 'paper', 'computing', 'machinery', 'and', 'intelligence', 'in', 'which', 'the', 'question', 'can', 'machines', 'think', 'is', 'replaced', 'with', 'the', 'question', 'can', 'machines', 'do', 'what', 'we', 'as', 'thinking', 'entities', 'can', 'do', 'in', 'turing', 's', 'proposal', 'the', 'various', 'characteristics', 'that', 'could', 'be', 'possessed', 'by', 'a', 'thinking', 'machine', 'and', 'the', 'various', 'implications', 'in', 'constructing', 'one', 'are', 'exposed', 'machine', 'learning', 'tasks', 'machine', 'learning', 'tasks', 'are', 'classified', 'into', 'several', 'broad', 'categories', 'in', 'supervised', 'learning', 'the', 'algorithm', 'builds', 'a', 'mathematical', 'model', 'from', 'a', 'set', 'of', 'data', 'that', 'contains', 'both', 'the', 'inputs', 'and', 'the', 'desired', 'outputs', 'for', 'example', 'if', 'the', 'task', 'were', 'determining', 'whether', 'an', 'image', 'contained', 'a', 'certain', 'object', 'the', 'training', 'data', 'for', 'a', 'supervised', 'learning', 'algorithm', 'would', 'include', 'images', 'with', 'and', 'without', 'that', 'object', 'the', 'input', 'and', 'each', 'image', 'would', 'have', 'a', 'label', 'the', 'output', 'designating', 'whether', 'it', 'contained', 'the', 'object', 'in', 'special', 'cases', 'the', 'input', 'may', 'be', 'only', 'partially', 'available', 'or', 'restricted', 'to', 'special', 'feedback', 'semi', 'supervised', 'learning', 'algorithms', ...

# %% [markdown]
# ### Build the gensim model for word2vec with by considering all the words with frequency >=1 with embedding size=50

# %%
#Build the model
model = gensim.models.Word2Vec(documents, #Word list
                               min_count = 1, #Ignore all words with total frequency lower than this                           
                               workers=4, #Number of CPUs
                               size=50,  #Embedding size
                               window=5, #Maximum Distance between current and predicted word
                               iter=10   #Number of iterations over the text corpus
                              )

# %% [markdown]
# ### Exploring the model

# %%
#Model size
model.wv.syn0.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
# (4448, 50)

# %% [markdown]
# #### Check how many words in the model

# %%
# Vocablury of the model
model.wv.vocab
# Out:
# {'machine': <gensim.models.keyedvectors.Vocab at 0x18fab135fd0>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x18fa1b055f8>,
#  'ml': <gensim.models.keyedvectors.Vocab at 0x18fa1a82ba8>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x18fab13b0f0>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x18fab13b128>,
#  'scientific': <gensim.models.keyedvectors.Vocab at 0x18fab13b048>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x18fab13b160>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x18fab13b198>,
#  'algorithms': <gensim.models.keyedvectors.Vocab at 0x18fab13b1d0>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x18fab13b208>,
#  'statistical': <gensim.models.keyedvectors.Vocab at 0x18fab13b240>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x18fab13b278>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x18fab13b2b0>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x18fab13b2e8>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x18fab13b320>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x18fab13b358>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x18fab13b390>,
#  'effectively': <gensim.models.keyedvectors.Vocab at 0x18fab13b3c8>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x18fab13b400>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x18fab13b438>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x18fab13b470>,
#  'task': <gensim.models.keyedvectors.Vocab at 0x18fab13b4a8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x18fab13b4e0>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x18fab13b518>,
#  'explicit': <gensim.models.keyedvectors.Vocab at 0x18fab13b550>,
#  'instructions': <gensim.models.keyedvectors.Vocab at 0x18fab13b588>,
#  'relying': <gensim.models.keyedvectors.Vocab at 0x18fab13b5c0>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x18fab13b5f8>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x18fab13b630>,
#  'inference': <gensim.models.keyedvectors.Vocab at 0x18fab13b668>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x18fab13b6a0>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x18fab13b6d8>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x18fab13b710>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x18fab13b748>,
#  'subset': <gensim.models.keyedvectors.Vocab at 0x18fab13b780>,
#  'artificial': <gensim.models.keyedvectors.Vocab at 0x18fab13b7b8>,
#  'intelligence': <gensim.models.keyedvectors.Vocab at 0x18fab13b7f0>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x18fab13b828>,
#  'mathematical': <gensim.models.keyedvectors.Vocab at 0x18fab13b860>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x18fab13b898>,
#  'sample': <gensim.models.keyedvectors.Vocab at 0x18fab13b8d0>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x18fab13b908>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x18fab13b940>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x18fab13b978>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x18fab13b9b0>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x18fab13b9e8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x18fab13ba20>,
#  'predictions': <gensim.models.keyedvectors.Vocab at 0x18fab13ba58>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x18fab13ba90>,
#  'decisions': <gensim.models.keyedvectors.Vocab at 0x18fab13bac8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x18fab13bb00>,
#  'explicitly': <gensim.models.keyedvectors.Vocab at 0x18fab13bb38>,
#  'programmed': <gensim.models.keyedvectors.Vocab at 0x18fab13bb70>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x18fab13bba8>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x18fab13bbe0>,
#  'applications': <gensim.models.keyedvectors.Vocab at 0x18fab13bc18>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x18fab13bc50>,
#  'filtering': <gensim.models.keyedvectors.Vocab at 0x18fab13bc88>,
#  'detection': <gensim.models.keyedvectors.Vocab at 0x18fab13bcc0>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x18fab13bcf8>,
#  'intruders': <gensim.models.keyedvectors.Vocab at 0x18fab13bd30>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x18fab13bd68>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x18fab13bda0>,
#  'infeasible': <gensim.models.keyedvectors.Vocab at 0x18fab13bdd8>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x18fab13be10>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x18fab13be48>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x18fab13be80>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x18fab13beb8>,
#  'performing': <gensim.models.keyedvectors.Vocab at 0x18fab13bef0>,
#  'closely': <gensim.models.keyedvectors.Vocab at 0x18fab13bf28>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x18fab13bf60>,
#  'computational': <gensim.models.keyedvectors.Vocab at 0x18fab13bf98>,
#  'statistics': <gensim.models.keyedvectors.Vocab at 0x18fab13bfd0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x18fab13e048>,
#  'focuses': <gensim.models.keyedvectors.Vocab at 0x18fab13e080>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x18fab13e0b8>,
#  'computers': <gensim.models.keyedvectors.Vocab at 0x18fab13e0f0>,
#  'optimization': <gensim.models.keyedvectors.Vocab at 0x18fab13e128>,
#  'delivers': <gensim.models.keyedvectors.Vocab at 0x18fab13e160>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x18fab13e198>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x18fab13e1d0>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x18fab13e208>,
#  'domains': <gensim.models.keyedvectors.Vocab at 0x18fab13e240>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x18fab13e278>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x18fab13e2b0>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x18fab13e2e8>,
#  'exploratory': <gensim.models.keyedvectors.Vocab at 0x18fab13e320>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x18fab13e358>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x18fab13e390>,
#  'unsupervised': <gensim.models.keyedvectors.Vocab at 0x18fab13e3c8>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x18fab13e400>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x18fab13e438>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x18fab13e470>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x18fab13e4a8>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x18fab13e4e0>,
#  'referred': <gensim.models.keyedvectors.Vocab at 0x18fab13e518>,
#  'predictive': <gensim.models.keyedvectors.Vocab at 0x18fab13e550>,
#  'analytics': <gensim.models.keyedvectors.Vocab at 0x18fab13e588>,
#  'overview': <gensim.models.keyedvectors.Vocab at 0x18fab13e5c0>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x18fab13e5f8>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x18fab13e630>,
#  'coined': <gensim.models.keyedvectors.Vocab at 0x18fab13e668>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x18fab13e6a0>,
#  'arthur': <gensim.models.keyedvectors.Vocab at 0x18fab13e6d8>,
#  'samuel': <gensim.models.keyedvectors.Vocab at 0x18fab13e710>,
#  'tom': <gensim.models.keyedvectors.Vocab at 0x18fab13e748>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x18fab13e780>,
#  'mitchell': <gensim.models.keyedvectors.Vocab at 0x18fab13e7b8>,
#  'provided': <gensim.models.keyedvectors.Vocab at 0x18fab13e7f0>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x18fab13e828>,
#  'quoted': <gensim.models.keyedvectors.Vocab at 0x18fab13e860>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x18fab13e898>,
#  'formal': <gensim.models.keyedvectors.Vocab at 0x18fab13e8d0>,
#  'definition': <gensim.models.keyedvectors.Vocab at 0x18fab13e908>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x18fab13e940>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x18fab13e978>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x18fab13e9b0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x18fab13e9e8>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x18fab13ea20>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x18fab13ea58>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x18fab13ea90>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x18fab13eac8>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x18fab13eb00>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x18fab13eb38>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x18fab13eb70>,
#  'tasks': <gensim.models.keyedvectors.Vocab at 0x18fab13eba8>,
#  't': <gensim.models.keyedvectors.Vocab at 0x18fab13ebe0>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x18fab13ec18>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x18fab13ec50>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x18fab13ec88>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x18fab13ecc0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x18fab13ecf8>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x18fab13ed30>,
#  'improves': <gensim.models.keyedvectors.Vocab at 0x18fab13ed68>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x18fab13eda0>,
#  'concerned': <gensim.models.keyedvectors.Vocab at 0x18fab13edd8>,
#  'offers': <gensim.models.keyedvectors.Vocab at 0x18fab13ee10>,
#  'fundamentally': <gensim.models.keyedvectors.Vocab at 0x18fab13ee48>,
#  'operational': <gensim.models.keyedvectors.Vocab at 0x18fab13ee80>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x18fab13eeb8>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x18fab13eef0>,
#  'defining': <gensim.models.keyedvectors.Vocab at 0x18fab13ef28>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x18fab13ef60>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x18fab13ef98>,
#  'follows': <gensim.models.keyedvectors.Vocab at 0x18fab13efd0>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x18fab141048>,
#  'turing': <gensim.models.keyedvectors.Vocab at 0x18fab141080>,
#  's': <gensim.models.keyedvectors.Vocab at 0x18fab1410b8>,
#  'proposal': <gensim.models.keyedvectors.Vocab at 0x18fab1410f0>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x18fab141128>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x18fab141160>,
#  'computing': <gensim.models.keyedvectors.Vocab at 0x18fab141198>,
#  'machinery': <gensim.models.keyedvectors.Vocab at 0x18fab1411d0>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x18fab141208>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x18fab141240>,
#  'machines': <gensim.models.keyedvectors.Vocab at 0x18fab141278>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x18fab1412b0>,
#  'replaced': <gensim.models.keyedvectors.Vocab at 0x18fab1412e8>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x18fab141320>,
#  'what': <gensim.models.keyedvectors.Vocab at 0x18fab141358>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x18fab141390>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x18fab1413c8>,
#  'entities': <gensim.models.keyedvectors.Vocab at 0x18fab141400>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x18fab141438>,
#  'characteristics': <gensim.models.keyedvectors.Vocab at 0x18fab141470>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x18fab1414a8>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x18fab1414e0>,
#  'possessed': <gensim.models.keyedvectors.Vocab at 0x18fab141518>,
#  'implications': <gensim.models.keyedvectors.Vocab at 0x18fab141550>,
#  'constructing': <gensim.models.keyedvectors.Vocab at 0x18fab141588>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x18fab1415c0>,
#  'exposed': <gensim.models.keyedvectors.Vocab at 0x18fab1415f8>,
#  'classified': <gensim.models.keyedvectors.Vocab at 0x18fab141630>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x18fab141668>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x18fab1416a0>,
#  'broad': <gensim.models.keyedvectors.Vocab at 0x18fab1416d8>,
#  'categories': <gensim.models.keyedvectors.Vocab at 0x18fab141710>,
#  'supervised': <gensim.models.keyedvectors.Vocab at 0x18fab141748>,
#  'builds': <gensim.models.keyedvectors.Vocab at 0x18fab141780>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x18fab1417b8>,
#  'contains': <gensim.models.keyedvectors.Vocab at 0x18fab1417f0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x18fab141828>,
#  'inputs': <gensim.models.keyedvectors.Vocab at 0x18fab141860>,
#  'desired': <gensim.models.keyedvectors.Vocab at 0x18fab141898>,
#  'outputs': <gensim.models.keyedvectors.Vocab at 0x18fab1418d0>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x18fab141908>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x18fab141940>,
#  'determining': <gensim.models.keyedvectors.Vocab at 0x18fab141978>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x18fab1419b0>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x18fab1419e8>,
#  'contained': <gensim.models.keyedvectors.Vocab at 0x18fab141a20>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x18fab141a58>,
#  'object': <gensim.models.keyedvectors.Vocab at 0x18fab141a90>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x18fab141ac8>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x18fab141b00>,
#  'images': <gensim.models.keyedvectors.Vocab at 0x18fab141b38>,
#  'input': <gensim.models.keyedvectors.Vocab at 0x18fab141b70>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x18fab141ba8>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x18fab141be0>,
#  'label': <gensim.models.keyedvectors.Vocab at 0x18fab141c18>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x18fab141c50>,
#  'designating': <gensim.models.keyedvectors.Vocab at 0x18fab141c88>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x18fab141cc0>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x18fab141cf8>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x18fab141d30>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x18fab141d68>,
#  'partially': <gensim.models.keyedvectors.Vocab at 0x18fab141da0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x18fab141dd8>,
#  'restricted': <gensim.models.keyedvectors.Vocab at 0x18fab141e10>,
#  'feedback': <gensim.models.keyedvectors.Vocab at 0x18fab141e48>,
#  'semi': <gensim.models.keyedvectors.Vocab at 0x18fab141e80>,
#  'incomplete': <gensim.models.keyedvectors.Vocab at 0x18fab141eb8>,
#  'portion': <gensim.models.keyedvectors.Vocab at 0x18fab141ef0>,
#  'doesn': <gensim.models.keyedvectors.Vocab at 0x18fab141f28>,
#  'labels': <gensim.models.keyedvectors.Vocab at 0x18fab141f60>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x18fab141f98>,
#  'regression': <gensim.models.keyedvectors.Vocab at 0x18fab141fd0>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x18fa1a82550>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x18f97fcfac8>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x18fa1a6da58>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x18fa1a878d0>,
#  'filters': <gensim.models.keyedvectors.Vocab at 0x18fa1a87080>,
#  'emails': <gensim.models.keyedvectors.Vocab at 0x18fa1a876a0>,
#  'incoming': <gensim.models.keyedvectors.Vocab at 0x18fa1a879b0>,
#  'folder': <gensim.models.keyedvectors.Vocab at 0x18fa1a87128>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x18fa1a87588>,
#  'identifies': <gensim.models.keyedvectors.Vocab at 0x18fa1a877f0>,
#  'spam': <gensim.models.keyedvectors.Vocab at 0x18fa1a87208>,
#  'prediction': <gensim.models.keyedvectors.Vocab at 0x18fa1a870b8>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x18fa1a87358>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x18fa1a87ef0>,
#  'represented': <gensim.models.keyedvectors.Vocab at 0x18fa1a87320>,
#  'boolean': <gensim.models.keyedvectors.Vocab at 0x18fa1a87908>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x18fa1a877b8>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x18fa1a87780>,
#  'named': <gensim.models.keyedvectors.Vocab at 0x18fa1a87978>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x18fa1a87898>,
#  'continuous': <gensim.models.keyedvectors.Vocab at 0x18fa1a876d8>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x18fa1a87550>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x18fa1a87668>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x18fa1a87c50>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x18fa1a87a58>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x18fa1b056d8>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x18fa1b05048>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x18fa1b050f0>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x18fa1b05588>,
#  'price': <gensim.models.keyedvectors.Vocab at 0x18fa1b05710>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x18fa1b05400>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x18fa1b05438>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x18fa1b05550>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x18fa1b05c88>,
#  'grouping': <gensim.models.keyedvectors.Vocab at 0x18fa1b053c8>,
#  'clustering': <gensim.models.keyedvectors.Vocab at 0x18fa1b055c0>,
#  'points': <gensim.models.keyedvectors.Vocab at 0x18fa1b05358>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x18fa1b05518>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x18fa1b054e0>,
#  'feature': <gensim.models.keyedvectors.Vocab at 0x18fa1b05470>,
#  'dimensionality': <gensim.models.keyedvectors.Vocab at 0x18fa1b054a8>,
#  'reduction': <gensim.models.keyedvectors.Vocab at 0x18fa1b052b0>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x18fa1b05198>,
#  'reducing': <gensim.models.keyedvectors.Vocab at 0x18fa1b05208>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x18fa1b05390>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x18fa1b05320>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x18fa1b051d0>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x18fa1b05160>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x18fa1b05278>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x18fa1b05128>,
#  'optimize': <gensim.models.keyedvectors.Vocab at 0x18fab145048>,
#  'choice': <gensim.models.keyedvectors.Vocab at 0x18fab145080>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x18fab1450b8>,
#  'acquire': <gensim.models.keyedvectors.Vocab at 0x18fab1450f0>,
#  'interactively': <gensim.models.keyedvectors.Vocab at 0x18fab145128>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x18fab145160>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x18fab145198>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x18fab1451d0>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x18fab145208>,
#  'labeling': <gensim.models.keyedvectors.Vocab at 0x18fab145240>,
#  'reinforcement': <gensim.models.keyedvectors.Vocab at 0x18fab145278>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x18fab1452b0>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x18fab1452e8>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x18fab145320>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x18fab145358>,
#  'dynamic': <gensim.models.keyedvectors.Vocab at 0x18fab145390>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x18fab1453c8>,
#  'autonomous': <gensim.models.keyedvectors.Vocab at 0x18fab145400>,
#  'vehicles': <gensim.models.keyedvectors.Vocab at 0x18fab145438>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x18fab145470>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x18fab1454a8>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x18fab1454e0>,
#  'opponent': <gensim.models.keyedvectors.Vocab at 0x18fab145518>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x18fab145550>,
#  'specialized': <gensim.models.keyedvectors.Vocab at 0x18fab145588>,
#  'topic': <gensim.models.keyedvectors.Vocab at 0x18fab1455c0>,
#  'modeling': <gensim.models.keyedvectors.Vocab at 0x18fab1455f8>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x18fab145630>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x18fab145668>,
#  'documents': <gensim.models.keyedvectors.Vocab at 0x18fab1456a0>,
#  'finds': <gensim.models.keyedvectors.Vocab at 0x18fab1456d8>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x18fab145710>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x18fab145748>,
#  'topics': <gensim.models.keyedvectors.Vocab at 0x18fab145780>,
#  'unobservable': <gensim.models.keyedvectors.Vocab at 0x18fab1457b8>,
#  'probability': <gensim.models.keyedvectors.Vocab at 0x18fab1457f0>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x18fab145828>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x18fab145860>,
#  'estimation': <gensim.models.keyedvectors.Vocab at 0x18fab145898>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x18fab1458d0>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x18fab145908>,
#  'inductive': <gensim.models.keyedvectors.Vocab at 0x18fab145940>,
#  'bias': <gensim.models.keyedvectors.Vocab at 0x18fab145978>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x18fab1459b0>,
#  'developmental': <gensim.models.keyedvectors.Vocab at 0x18fab1459e8>,
#  'robotics': <gensim.models.keyedvectors.Vocab at 0x18fab145a20>,
#  'robot': <gensim.models.keyedvectors.Vocab at 0x18fab145a58>,
#  'generate': <gensim.models.keyedvectors.Vocab at 0x18fab145a90>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x18fab145ac8>,
#  'experiences': <gensim.models.keyedvectors.Vocab at 0x18fab145b00>,
#  'curriculum': <gensim.models.keyedvectors.Vocab at 0x18fab145b38>,
#  'cumulatively': <gensim.models.keyedvectors.Vocab at 0x18fab145b70>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x18fab145ba8>,
#  'skills': <gensim.models.keyedvectors.Vocab at 0x18fab145be0>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x18fab145c18>,
#  'guided': <gensim.models.keyedvectors.Vocab at 0x18fab145c50>,
#  'exploration': <gensim.models.keyedvectors.Vocab at 0x18fab145c88>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x18fab145cc0>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x18fab145cf8>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x18fab145d30>,
#  'robots': <gensim.models.keyedvectors.Vocab at 0x18fab145d68>,
#  'guidance': <gensim.models.keyedvectors.Vocab at 0x18fab145da0>,
#  'mechanisms': <gensim.models.keyedvectors.Vocab at 0x18fab145dd8>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x18fab145e10>,
#  'maturation': <gensim.models.keyedvectors.Vocab at 0x18fab145e48>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x18fab145e80>,
#  'synergies': <gensim.models.keyedvectors.Vocab at 0x18fab145eb8>,
#  'imitation': <gensim.models.keyedvectors.Vocab at 0x18fab145ef0>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x18fab145f28>,
#  'relationships': <gensim.models.keyedvectors.Vocab at 0x18fab145f60>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x18fab145f98>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x18fab145fd0>,
#  'pioneer': <gensim.models.keyedvectors.Vocab at 0x18fab147048>,
#  'gaming': <gensim.models.keyedvectors.Vocab at 0x18fab147080>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x18fab1470b8>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x18fab1470f0>,
#  'ibm': <gensim.models.keyedvectors.Vocab at 0x18fab147128>,
#  'endeavour': <gensim.models.keyedvectors.Vocab at 0x18fab147160>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x18fab147198>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x18fab1471d0>,
#  'quest': <gensim.models.keyedvectors.Vocab at 0x18fab147208>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x18fab147240>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x18fab147278>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x18fab1472b0>,
#  'ai': <gensim.models.keyedvectors.Vocab at 0x18fab1472e8>,
#  'academic': <gensim.models.keyedvectors.Vocab at 0x18fab147320>,
#  'discipline': <gensim.models.keyedvectors.Vocab at 0x18fab147358>,
#  'researchers': <gensim.models.keyedvectors.Vocab at 0x18fab147390>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x18fab1473c8>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x18fab147400>,
#  'attempted': <gensim.models.keyedvectors.Vocab at 0x18fab147438>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x18fab147470>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x18fab1474a8>,
#  'symbolic': <gensim.models.keyedvectors.Vocab at 0x18fab1474e0>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x18fab147518>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x18fab147550>,
#  'termed': <gensim.models.keyedvectors.Vocab at 0x18fab147588>,
#  'neural': <gensim.models.keyedvectors.Vocab at 0x18fab1475c0>,
#  'networks': <gensim.models.keyedvectors.Vocab at 0x18fab1475f8>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x18fab147630>,
#  'perceptrons': <gensim.models.keyedvectors.Vocab at 0x18fab147668>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x18fab1476a0>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x18fab1476d8>,
#  'reinventions': <gensim.models.keyedvectors.Vocab at 0x18fab147710>,
#  'generalized': <gensim.models.keyedvectors.Vocab at 0x18fab147748>,
#  'linear': <gensim.models.keyedvectors.Vocab at 0x18fab147780>,
#  'probabilistic': <gensim.models.keyedvectors.Vocab at 0x18fab1477b8>,
#  'reasoning': <gensim.models.keyedvectors.Vocab at 0x18fab1477f0>,
#  'employed': <gensim.models.keyedvectors.Vocab at 0x18fab147828>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x18fab147860>,
#  'automated': <gensim.models.keyedvectors.Vocab at 0x18fab147898>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x18fab1478d0>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x18fab147908>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x18fab147940>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x18fab147978>,
#  'emphasis': <gensim.models.keyedvectors.Vocab at 0x18fab1479b0>,
#  'logical': <gensim.models.keyedvectors.Vocab at 0x18fab1479e8>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x18fab147a20>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x18fab147a58>,
#  'rift': <gensim.models.keyedvectors.Vocab at 0x18fab147a90>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x18fab147ac8>,
#  'plagued': <gensim.models.keyedvectors.Vocab at 0x18fab147b00>,
#  'theoretical': <gensim.models.keyedvectors.Vocab at 0x18fab147b38>,
#  'practical': <gensim.models.keyedvectors.Vocab at 0x18fab147b70>,
#  'acquisition': <gensim.models.keyedvectors.Vocab at 0x18fab147ba8>,
#  'representation': <gensim.models.keyedvectors.Vocab at 0x18fab147be0>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x18fab147c18>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x18fab147c50>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x18fab147c88>,
#  'dominate': <gensim.models.keyedvectors.Vocab at 0x18fab147cc0>,
#  'favor': <gensim.models.keyedvectors.Vocab at 0x18fab147cf8>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x18fab147d30>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x18fab147d68>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x18fab147da0>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x18fab147dd8>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x18fab147e10>,
#  'programming': <gensim.models.keyedvectors.Vocab at 0x18fab147e48>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x18fab147e80>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x18fab147eb8>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x18fab147ef0>,
#  'now': <gensim.models.keyedvectors.Vocab at 0x18fab147f28>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x18fab147f60>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x18fab147f98>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x18fab147fd0>,
#  'recognition': <gensim.models.keyedvectors.Vocab at 0x18fab14b048>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x18fab14b080>,
#  'retrieval': <gensim.models.keyedvectors.Vocab at 0x18fab14b0b8>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x18fab14b0f0>,
#  'abandoned': <gensim.models.keyedvectors.Vocab at 0x18fab14b128>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x18fab14b160>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x18fab14b198>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x18fab14b1d0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x18fab14b208>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x18fab14b240>,
#  'continued': <gensim.models.keyedvectors.Vocab at 0x18fab14b278>,
#  'cs': <gensim.models.keyedvectors.Vocab at 0x18fab14b2b0>,
#  'connectionism': <gensim.models.keyedvectors.Vocab at 0x18fab14b2e8>,
#  'disciplines': <gensim.models.keyedvectors.Vocab at 0x18fab14b320>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x18fab14b358>,
#  'hopfield': <gensim.models.keyedvectors.Vocab at 0x18fab14b390>,
#  'rumelhart': <gensim.models.keyedvectors.Vocab at 0x18fab14b3c8>,
#  'hinton': <gensim.models.keyedvectors.Vocab at 0x18fab14b400>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x18fab14b438>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x18fab14b470>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x18fab14b4a8>,
#  'mid': <gensim.models.keyedvectors.Vocab at 0x18fab14b4e0>,
#  'reinvention': <gensim.models.keyedvectors.Vocab at 0x18fab14b518>,
#  'backpropagation': <gensim.models.keyedvectors.Vocab at 0x18fab14b550>,
#  'reorganized': <gensim.models.keyedvectors.Vocab at 0x18fab14b588>,
#  'separate': <gensim.models.keyedvectors.Vocab at 0x18fab14b5c0>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x18fab14b5f8>,
#  'flourish': <gensim.models.keyedvectors.Vocab at 0x18fab14b630>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x18fab14b668>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x18fab14b6a0>,
#  'achieving': <gensim.models.keyedvectors.Vocab at 0x18fab14b6d8>,
#  'tackling': <gensim.models.keyedvectors.Vocab at 0x18fab14b710>,
#  'solvable': <gensim.models.keyedvectors.Vocab at 0x18fab14b748>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x18fab14b780>,
#  'shifted': <gensim.models.keyedvectors.Vocab at 0x18fab14b7b8>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x18fab14b7f0>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x18fab14b828>,
#  'approaches': <gensim.models.keyedvectors.Vocab at 0x18fab14b860>,
#  'inherited': <gensim.models.keyedvectors.Vocab at 0x18fab14b898>,
#  'toward': <gensim.models.keyedvectors.Vocab at 0x18fab14b8d0>,
#  'borrowed': <gensim.models.keyedvectors.Vocab at 0x18fab14b908>,
#  'benefited': <gensim.models.keyedvectors.Vocab at 0x18fab14b940>,
#  'availability': <gensim.models.keyedvectors.Vocab at 0x18fab14b978>,
#  'digitized': <gensim.models.keyedvectors.Vocab at 0x18fab14b9b0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x18fab14b9e8>,
#  'distribute': <gensim.models.keyedvectors.Vocab at 0x18fab14ba20>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x18fab14ba58>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x18fab14ba90>,
#  'relation': <gensim.models.keyedvectors.Vocab at 0x18fab14bac8>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x18fab14bb00>,
#  'employ': <gensim.models.keyedvectors.Vocab at 0x18fab14bb38>,
#  'overlap': <gensim.models.keyedvectors.Vocab at 0x18fab14bb70>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x18fab14bba8>,
#  'properties': <gensim.models.keyedvectors.Vocab at 0x18fab14bbe0>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x18fab14bc18>,
#  'discovery': <gensim.models.keyedvectors.Vocab at 0x18fab14bc50>,
#  'previously': <gensim.models.keyedvectors.Vocab at 0x18fab14bc88>,
#  'unknown': <gensim.models.keyedvectors.Vocab at 0x18fab14bcc0>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x18fab14bcf8>,
#  'databases': <gensim.models.keyedvectors.Vocab at 0x18fab14bd30>,
#  'uses': <gensim.models.keyedvectors.Vocab at 0x18fab14bd68>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x18fab14bda0>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x18fab14bdd8>,
#  'goals': <gensim.models.keyedvectors.Vocab at 0x18fab14be10>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x18fab14be48>,
#  'employs': <gensim.models.keyedvectors.Vocab at 0x18fab14be80>,
#  'preprocessing': <gensim.models.keyedvectors.Vocab at 0x18fab14beb8>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x18fab14bef0>,
#  'learner': <gensim.models.keyedvectors.Vocab at 0x18fab14bf28>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x18fab14bf60>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x18fab14bf98>,
#  'confusion': <gensim.models.keyedvectors.Vocab at 0x18fab14bfd0>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x18fab14f048>,
#  'communities': <gensim.models.keyedvectors.Vocab at 0x18fab14f080>,
#  'conferences': <gensim.models.keyedvectors.Vocab at 0x18fab14f0b8>,
#  'journals': <gensim.models.keyedvectors.Vocab at 0x18fab14f0f0>,
#  'ecml': <gensim.models.keyedvectors.Vocab at 0x18fab14f128>,
#  'pkdd': <gensim.models.keyedvectors.Vocab at 0x18fab14f160>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x18fab14f198>,
#  'exception': <gensim.models.keyedvectors.Vocab at 0x18fab14f1d0>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x18fab14f208>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x18fab14f240>,
#  'assumptions': <gensim.models.keyedvectors.Vocab at 0x18fab14f278>,
#  'usually': <gensim.models.keyedvectors.Vocab at 0x18fab14f2b0>,
#  'evaluated': <gensim.models.keyedvectors.Vocab at 0x18fab14f2e8>,
#  'reproduce': <gensim.models.keyedvectors.Vocab at 0x18fab14f320>,
#  'kdd': <gensim.models.keyedvectors.Vocab at 0x18fab14f358>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x18fab14f390>,
#  'uninformed': <gensim.models.keyedvectors.Vocab at 0x18fab14f3c8>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x18fab14f400>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x18fab14f438>,
#  'outperformed': <gensim.models.keyedvectors.Vocab at 0x18fab14f470>,
#  'typical': <gensim.models.keyedvectors.Vocab at 0x18fab14f4a8>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x18fab14f4e0>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x18fab14f518>,
#  'unavailability': <gensim.models.keyedvectors.Vocab at 0x18fab14f550>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x18fab14f588>,
#  'intimate': <gensim.models.keyedvectors.Vocab at 0x18fab14f5c0>,
#  'ties': <gensim.models.keyedvectors.Vocab at 0x18fab14f5f8>,
#  'formulated': <gensim.models.keyedvectors.Vocab at 0x18fab14f630>,
#  'minimization': <gensim.models.keyedvectors.Vocab at 0x18fab14f668>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x18fab14f6a0>,
#  'functions': <gensim.models.keyedvectors.Vocab at 0x18fab14f6d8>,
#  'express': <gensim.models.keyedvectors.Vocab at 0x18fab14f710>,
#  'discrepancy': <gensim.models.keyedvectors.Vocab at 0x18fab14f748>,
#  'trained': <gensim.models.keyedvectors.Vocab at 0x18fab14f780>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x18fab14f7b8>,
#  'instances': <gensim.models.keyedvectors.Vocab at 0x18fab14f7f0>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x18fab14f828>,
#  'assign': <gensim.models.keyedvectors.Vocab at 0x18fab14f860>,
#  'correctly': <gensim.models.keyedvectors.Vocab at 0x18fab14f898>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x18fab14f8d0>,
#  'pre': <gensim.models.keyedvectors.Vocab at 0x18fab14f908>,
#  'assigned': <gensim.models.keyedvectors.Vocab at 0x18fab14f940>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x18fab14f978>,
#  'arises': <gensim.models.keyedvectors.Vocab at 0x18fab14f9b0>,
#  'generalization': <gensim.models.keyedvectors.Vocab at 0x18fab14f9e8>,
#  'minimize': <gensim.models.keyedvectors.Vocab at 0x18fab14fa20>,
#  'minimizing': <gensim.models.keyedvectors.Vocab at 0x18fab14fa58>,
#  'unseen': <gensim.models.keyedvectors.Vocab at 0x18fab14fa90>,
#  'samples': <gensim.models.keyedvectors.Vocab at 0x18fab14fac8>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x18fab14fb00>,
#  'michael': <gensim.models.keyedvectors.Vocab at 0x18fab14fb38>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x18fab14fb70>,
#  'jordan': <gensim.models.keyedvectors.Vocab at 0x18fab14fba8>,
#  'ideas': <gensim.models.keyedvectors.Vocab at 0x18fab14fbe0>,
#  'methodological': <gensim.models.keyedvectors.Vocab at 0x18fab14fc18>,
#  'principles': <gensim.models.keyedvectors.Vocab at 0x18fab14fc50>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x18fab14fc88>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x18fab14fcc0>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x18fab14fcf8>,
#  'suggested': <gensim.models.keyedvectors.Vocab at 0x18fab14fd30>,
#  'placeholder': <gensim.models.keyedvectors.Vocab at 0x18fab14fd68>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x18fab14fda0>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x18fab14fdd8>,
#  'leo': <gensim.models.keyedvectors.Vocab at 0x18fab14fe10>,
#  'breiman': <gensim.models.keyedvectors.Vocab at 0x18fab14fe48>,
#  'distinguished': <gensim.models.keyedvectors.Vocab at 0x18fab14fe80>,
#  'modelling': <gensim.models.keyedvectors.Vocab at 0x18fab14feb8>,
#  'paradigms': <gensim.models.keyedvectors.Vocab at 0x18fab14fef0>,
#  'algorithmic': <gensim.models.keyedvectors.Vocab at 0x18fab14ff28>,
#  'wherein': <gensim.models.keyedvectors.Vocab at 0x18fab14ff60>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x18fab14ff98>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x18fab14ffd0>,
#  'random': <gensim.models.keyedvectors.Vocab at 0x18fab151048>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x18fab151080>,
#  'statisticians': <gensim.models.keyedvectors.Vocab at 0x18fab1510b8>,
#  'adopted': <gensim.models.keyedvectors.Vocab at 0x18fab1510f0>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x18fab151128>,
#  'core': <gensim.models.keyedvectors.Vocab at 0x18fab151160>,
#  'objective': <gensim.models.keyedvectors.Vocab at 0x18fab151198>,
#  'generalize': <gensim.models.keyedvectors.Vocab at 0x18fab1511d0>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x18fab151208>,
#  'accurately': <gensim.models.keyedvectors.Vocab at 0x18fab151240>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x18fab151278>,
#  'experienced': <gensim.models.keyedvectors.Vocab at 0x18fab1512b0>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x18fab1512e8>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x18fab151320>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x18fab151358>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x18fab151390>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x18fab1513c8>,
#  'occurrences': <gensim.models.keyedvectors.Vocab at 0x18fab151400>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x18fab151438>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x18fab151470>,
#  'enables': <gensim.models.keyedvectors.Vocab at 0x18fab1514a8>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x18fab1514e0>,
#  'sufficiently': <gensim.models.keyedvectors.Vocab at 0x18fab151518>,
#  'accurate': <gensim.models.keyedvectors.Vocab at 0x18fab151550>,
#  'branch': <gensim.models.keyedvectors.Vocab at 0x18fab151588>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x18fab1515c0>,
#  'sets': <gensim.models.keyedvectors.Vocab at 0x18fab1515f8>,
#  'finite': <gensim.models.keyedvectors.Vocab at 0x18fab151630>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x18fab151668>,
#  'uncertain': <gensim.models.keyedvectors.Vocab at 0x18fab1516a0>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x18fab1516d8>,
#  'yield': <gensim.models.keyedvectors.Vocab at 0x18fab151710>,
#  'guarantees': <gensim.models.keyedvectors.Vocab at 0x18fab151748>,
#  'bounds': <gensim.models.keyedvectors.Vocab at 0x18fab151780>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x18fab1517b8>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x18fab1517f0>,
#  'variance': <gensim.models.keyedvectors.Vocab at 0x18fab151828>,
#  'decomposition': <gensim.models.keyedvectors.Vocab at 0x18fab151860>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x18fab151898>,
#  'quantify': <gensim.models.keyedvectors.Vocab at 0x18fab1518d0>,
#  'error': <gensim.models.keyedvectors.Vocab at 0x18fab151908>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x18fab151940>,
#  'complexity': <gensim.models.keyedvectors.Vocab at 0x18fab151978>,
#  'hypothesis': <gensim.models.keyedvectors.Vocab at 0x18fab1519b0>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x18fab1519e8>,
#  'match': <gensim.models.keyedvectors.Vocab at 0x18fab151a20>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x18fab151a58>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x18fab151a90>,
#  'underfit': <gensim.models.keyedvectors.Vocab at 0x18fab151ac8>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x18fab151b00>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x18fab151b38>,
#  'decreases': <gensim.models.keyedvectors.Vocab at 0x18fab151b70>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x18fab151ba8>,
#  'overfitting': <gensim.models.keyedvectors.Vocab at 0x18fab151be0>,
#  'poorer': <gensim.models.keyedvectors.Vocab at 0x18fab151c18>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x18fab151c50>,
#  'theorists': <gensim.models.keyedvectors.Vocab at 0x18fab151c88>,
#  'feasibility': <gensim.models.keyedvectors.Vocab at 0x18fab151cc0>,
#  'computation': <gensim.models.keyedvectors.Vocab at 0x18fab151cf8>,
#  'feasible': <gensim.models.keyedvectors.Vocab at 0x18fab151d30>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x18fab151d68>,
#  'polynomial': <gensim.models.keyedvectors.Vocab at 0x18fab151da0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x18fab151dd8>,
#  'kinds': <gensim.models.keyedvectors.Vocab at 0x18fab151e10>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x18fab151e48>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x18fab151e80>,
#  'classes': <gensim.models.keyedvectors.Vocab at 0x18fab151eb8>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x18fab151ef0>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x18fab151f28>,
#  'intended': <gensim.models.keyedvectors.Vocab at 0x18fab151f60>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x18fab151f98>,
#  'consists': <gensim.models.keyedvectors.Vocab at 0x18fab151fd0>,
#  'supervisory': <gensim.models.keyedvectors.Vocab at 0x18fab156048>,
#  'signal': <gensim.models.keyedvectors.Vocab at 0x18fab156080>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x18fab1560b8>,
#  'missing': <gensim.models.keyedvectors.Vocab at 0x18fab1560f0>,
#  'array': <gensim.models.keyedvectors.Vocab at 0x18fab156128>,
#  'vector': <gensim.models.keyedvectors.Vocab at 0x18fab156160>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x18fab156198>,
#  'iterative': <gensim.models.keyedvectors.Vocab at 0x18fab1561d0>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x18fab156208>,
#  'optimal': <gensim.models.keyedvectors.Vocab at 0x18fab156240>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x18fab156278>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x18fab1562b0>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x18fab1562e8>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x18fab156320>,
#  'numerical': <gensim.models.keyedvectors.Vocab at 0x18fab156358>,
#  'similarity': <gensim.models.keyedvectors.Vocab at 0x18fab156390>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x18fab1563c8>,
#  'measures': <gensim.models.keyedvectors.Vocab at 0x18fab156400>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x18fab156438>,
#  'objects': <gensim.models.keyedvectors.Vocab at 0x18fab156470>,
#  'ranking': <gensim.models.keyedvectors.Vocab at 0x18fab1564a8>,
#  'recommendation': <gensim.models.keyedvectors.Vocab at 0x18fab1564e0>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x18fab156518>,
#  'identity': <gensim.models.keyedvectors.Vocab at 0x18fab156550>,
#  'tracking': <gensim.models.keyedvectors.Vocab at 0x18fab156588>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x18fab1565c0>,
#  'verification': <gensim.models.keyedvectors.Vocab at 0x18fab1565f8>,
#  'speaker': <gensim.models.keyedvectors.Vocab at 0x18fab156630>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x18fab156668>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x18fab1566a0>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x18fab1566d8>,
#  'labeled': <gensim.models.keyedvectors.Vocab at 0x18fab156710>,
#  'categorized': <gensim.models.keyedvectors.Vocab at 0x18fab156748>,
#  'responding': <gensim.models.keyedvectors.Vocab at 0x18fab156780>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x18fab1567b8>,
#  'commonalities': <gensim.models.keyedvectors.Vocab at 0x18fab1567f0>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x18fab156828>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x18fab156860>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x18fab156898>,
#  'piece': <gensim.models.keyedvectors.Vocab at 0x18fab1568d0>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x18fab156908>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x18fab156940>,
#  'encompasses': <gensim.models.keyedvectors.Vocab at 0x18fab156978>,
#  'involving': <gensim.models.keyedvectors.Vocab at 0x18fab1569b0>,
#  'summarizing': <gensim.models.keyedvectors.Vocab at 0x18fab1569e8>,
#  'explaining': <gensim.models.keyedvectors.Vocab at 0x18fab156a20>,
#  'cluster': <gensim.models.keyedvectors.Vocab at 0x18fab156a58>,
#  'assignment': <gensim.models.keyedvectors.Vocab at 0x18fab156a90>,
#  'observations': <gensim.models.keyedvectors.Vocab at 0x18fab156ac8>,
#  'subsets': <gensim.models.keyedvectors.Vocab at 0x18fab156b00>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x18fab156b38>,
#  'clusters': <gensim.models.keyedvectors.Vocab at 0x18fab156b70>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x18fab156ba8>,
#  'predesignated': <gensim.models.keyedvectors.Vocab at 0x18fab156be0>,
#  'criteria': <gensim.models.keyedvectors.Vocab at 0x18fab156c18>,
#  'drawn': <gensim.models.keyedvectors.Vocab at 0x18fab156c50>,
#  'dissimilar': <gensim.models.keyedvectors.Vocab at 0x18fab156c88>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x18fab156cc0>,
#  'defined': <gensim.models.keyedvectors.Vocab at 0x18fab156cf8>,
#  'metric': <gensim.models.keyedvectors.Vocab at 0x18fab156d30>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x18fab156d68>,
#  'compactness': <gensim.models.keyedvectors.Vocab at 0x18fab156da0>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x18fab156dd8>,
#  'separation': <gensim.models.keyedvectors.Vocab at 0x18fab156e10>,
#  'estimated': <gensim.models.keyedvectors.Vocab at 0x18fab156e48>,
#  'graph': <gensim.models.keyedvectors.Vocab at 0x18fab156e80>,
#  'connectivity': <gensim.models.keyedvectors.Vocab at 0x18fab156eb8>,
#  'software': <gensim.models.keyedvectors.Vocab at 0x18fab156ef0>,
#  'agents': <gensim.models.keyedvectors.Vocab at 0x18fab156f28>,
#  'ought': <gensim.models.keyedvectors.Vocab at 0x18fab156f60>,
#  'actions': <gensim.models.keyedvectors.Vocab at 0x18fab156f98>,
#  'maximize': <gensim.models.keyedvectors.Vocab at 0x18fab156fd0>,
#  'notion': <gensim.models.keyedvectors.Vocab at 0x18fab159048>,
#  'cumulative': <gensim.models.keyedvectors.Vocab at 0x18fab159080>,
#  'reward': <gensim.models.keyedvectors.Vocab at 0x18fab1590b8>,
#  'generality': <gensim.models.keyedvectors.Vocab at 0x18fab1590f0>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x18fab159128>,
#  'operations': <gensim.models.keyedvectors.Vocab at 0x18fab159160>,
#  'simulation': <gensim.models.keyedvectors.Vocab at 0x18fab159198>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x18fab1591d0>,
#  'agent': <gensim.models.keyedvectors.Vocab at 0x18fab159208>,
#  'swarm': <gensim.models.keyedvectors.Vocab at 0x18fab159240>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x18fab159278>,
#  'typically': <gensim.models.keyedvectors.Vocab at 0x18fab1592b0>,
#  'markov': <gensim.models.keyedvectors.Vocab at 0x18fab1592e8>,
#  'decision': <gensim.models.keyedvectors.Vocab at 0x18fab159320>,
#  'mdp': <gensim.models.keyedvectors.Vocab at 0x18fab159358>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x18fab159390>,
#  'exact': <gensim.models.keyedvectors.Vocab at 0x18fab1593c8>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x18fab159400>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x18fab159438>,
#  'enhance': <gensim.models.keyedvectors.Vocab at 0x18fab159470>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x18fab1594a8>,
#  'discovering': <gensim.models.keyedvectors.Vocab at 0x18fab1594e0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x18fab159518>,
#  'representations': <gensim.models.keyedvectors.Vocab at 0x18fab159550>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x18fab159588>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x18fab1595c0>,
#  'principal': <gensim.models.keyedvectors.Vocab at 0x18fab1595f8>,
#  'components': <gensim.models.keyedvectors.Vocab at 0x18fab159630>,
#  'attempt': <gensim.models.keyedvectors.Vocab at 0x18fab159668>,
#  'preserve': <gensim.models.keyedvectors.Vocab at 0x18fab1596a0>,
#  'transform': <gensim.models.keyedvectors.Vocab at 0x18fab1596d8>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x18fab159710>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x18fab159748>,
#  'processing': <gensim.models.keyedvectors.Vocab at 0x18fab159780>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x18fab1597b8>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x18fab1597f0>,
#  'allows': <gensim.models.keyedvectors.Vocab at 0x18fab159828>,
#  'reconstruction': <gensim.models.keyedvectors.Vocab at 0x18fab159860>,
# ...
#  'manifold': <gensim.models.keyedvectors.Vocab at 0x18fab159cc0>,
#  'constraint': <gensim.models.keyedvectors.Vocab at 0x18fab159cf8>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x18fab159d30>,
#  'dimensional': <gensim.models.keyedvectors.Vocab at 0x18fab159d68>,
#  'sparse': <gensim.models.keyedvectors.Vocab at 0x18fab159da0>,
#  'coding': <gensim.models.keyedvectors.Vocab at 0x18fab159dd8>,
#  'zeros': <gensim.models.keyedvectors.Vocab at 0x18fab159e10>,
#  'multilinear': <gensim.models.keyedvectors.Vocab at 0x18fab159e48>,
#  'subspace': <gensim.models.keyedvectors.Vocab at 0x18fab159e80>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x18fab159eb8>,
#  'tensor': <gensim.models.keyedvectors.Vocab at 0x18fab159ef0>,
#  'multidimensional': <gensim.models.keyedvectors.Vocab at 0x18fab159f28>,
#  'reshaping': <gensim.models.keyedvectors.Vocab at 0x18fab159f60>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x18fab159f98>,
#  'vectors': <gensim.models.keyedvectors.Vocab at 0x18fab159fd0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x18fab15d048>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x18fab15d080>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x18fab15d0b8>,
#  'hierarchy': <gensim.models.keyedvectors.Vocab at 0x18fab15d0f0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x18fab15d128>,
#  'abstract': <gensim.models.keyedvectors.Vocab at 0x18fab15d160>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x18fab15d198>,
#  'argued': <gensim.models.keyedvectors.Vocab at 0x18fab15d1d0>,
#  'intelligent': <gensim.models.keyedvectors.Vocab at 0x18fab15d208>,
#  'learns': <gensim.models.keyedvectors.Vocab at 0x18fab15d240>,
#  'disentangles': <gensim.models.keyedvectors.Vocab at 0x18fab15d278>,
#  'factors': <gensim.models.keyedvectors.Vocab at 0x18fab15d2b0>,
#  'variation': <gensim.models.keyedvectors.Vocab at 0x18fab15d2e8>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x18fab15d320>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x18fab15d358>,
#  'motivated': <gensim.models.keyedvectors.Vocab at 0x18fab15d390>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x18fab15d3c8>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x18fab15d400>,
#  'mathematically': <gensim.models.keyedvectors.Vocab at 0x18fab15d438>,
#  'computationally': <gensim.models.keyedvectors.Vocab at 0x18fab15d470>,
#  'convenient': <gensim.models.keyedvectors.Vocab at 0x18fab15d4a8>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x18fab15d4e0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x18fab15d518>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x18fab15d550>,
#  'sensory': <gensim.models.keyedvectors.Vocab at 0x18fab15d588>,
#  'yielded': <gensim.models.keyedvectors.Vocab at 0x18fab15d5c0>,
#  'attempts': <gensim.models.keyedvectors.Vocab at 0x18fab15d5f8>,
#  'algorithmically': <gensim.models.keyedvectors.Vocab at 0x18fab15d630>,
#  'define': <gensim.models.keyedvectors.Vocab at 0x18fab15d668>,
#  'alternative': <gensim.models.keyedvectors.Vocab at 0x18fab15d6a0>,
#  'examination': <gensim.models.keyedvectors.Vocab at 0x18fab15d6d8>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x18fab15d710>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x18fab15d748>,
#  'assumed': <gensim.models.keyedvectors.Vocab at 0x18fab15d780>,
#  'strongly': <gensim.models.keyedvectors.Vocab at 0x18fab15d7b8>,
#  'np': <gensim.models.keyedvectors.Vocab at 0x18fab15d7f0>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x18fab15d828>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x18fab15d860>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x18fab15d898>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x18fab15d8d0>,
#  'heuristic': <gensim.models.keyedvectors.Vocab at 0x18fab15d908>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x18fab15d940>,
#  'svd': <gensim.models.keyedvectors.Vocab at 0x18fab15d978>,
#  'contexts': <gensim.models.keyedvectors.Vocab at 0x18fab15d9b0>,
#  'belongs': <gensim.models.keyedvectors.Vocab at 0x18fab15d9e8>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x18fab15da20>,
#  'sparsely': <gensim.models.keyedvectors.Vocab at 0x18fab15da58>,
#  'corresponding': <gensim.models.keyedvectors.Vocab at 0x18fab15da90>,
#  'de': <gensim.models.keyedvectors.Vocab at 0x18fab15dac8>,
#  'noising': <gensim.models.keyedvectors.Vocab at 0x18fab15db00>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x18fab15db38>,
#  'clean': <gensim.models.keyedvectors.Vocab at 0x18fab15db70>,
#  'patch': <gensim.models.keyedvectors.Vocab at 0x18fab15dba8>,
#  'noise': <gensim.models.keyedvectors.Vocab at 0x18fab15dbe0>,
#  'anomaly': <gensim.models.keyedvectors.Vocab at 0x18fab15dc18>,
#  'outlier': <gensim.models.keyedvectors.Vocab at 0x18fab15dc50>,
#  'identification': <gensim.models.keyedvectors.Vocab at 0x18fab15dc88>,
#  'rare': <gensim.models.keyedvectors.Vocab at 0x18fab15dcc0>,
#  'items': <gensim.models.keyedvectors.Vocab at 0x18fab15dcf8>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x18fab15dd30>,
#  'raise': <gensim.models.keyedvectors.Vocab at 0x18fab15dd68>,
#  'suspicions': <gensim.models.keyedvectors.Vocab at 0x18fab15dda0>,
#  'differing': <gensim.models.keyedvectors.Vocab at 0x18fab15ddd8>,
#  'majority': <gensim.models.keyedvectors.Vocab at 0x18fab15de10>,
#  'anomalous': <gensim.models.keyedvectors.Vocab at 0x18fab15de48>,
#  'represent': <gensim.models.keyedvectors.Vocab at 0x18fab15de80>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x18fab15deb8>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x18fab15def0>,
#  'fraud': <gensim.models.keyedvectors.Vocab at 0x18fab15df28>,
#  'structural': <gensim.models.keyedvectors.Vocab at 0x18fab15df60>,
#  'defect': <gensim.models.keyedvectors.Vocab at 0x18fab15df98>,
#  'errors': <gensim.models.keyedvectors.Vocab at 0x18fab15dfd0>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x18fab160048>,
#  'anomalies': <gensim.models.keyedvectors.Vocab at 0x18fab160080>,
#  'outliers': <gensim.models.keyedvectors.Vocab at 0x18fab1600b8>,
#  'novelties': <gensim.models.keyedvectors.Vocab at 0x18fab1600f0>,
#  'deviations': <gensim.models.keyedvectors.Vocab at 0x18fab160128>,
#  'exceptions': <gensim.models.keyedvectors.Vocab at 0x18fab160160>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x18fab160198>,
#  'abuse': <gensim.models.keyedvectors.Vocab at 0x18fab1601d0>,
#  'intrusion': <gensim.models.keyedvectors.Vocab at 0x18fab160208>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x18fab160240>,
#  'unexpected': <gensim.models.keyedvectors.Vocab at 0x18fab160278>,
#  'bursts': <gensim.models.keyedvectors.Vocab at 0x18fab1602b0>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x18fab1602e8>,
#  'adhere': <gensim.models.keyedvectors.Vocab at 0x18fab160320>,
#  'fail': <gensim.models.keyedvectors.Vocab at 0x18fab160358>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x18fab160390>,
#  'aggregated': <gensim.models.keyedvectors.Vocab at 0x18fab1603c8>,
#  'appropriately': <gensim.models.keyedvectors.Vocab at 0x18fab160400>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x18fab160438>,
#  'detect': <gensim.models.keyedvectors.Vocab at 0x18fab160470>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x18fab1604a8>,
#  'formed': <gensim.models.keyedvectors.Vocab at 0x18fab1604e0>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x18fab160518>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x18fab160550>,
#  'assumption': <gensim.models.keyedvectors.Vocab at 0x18fab160588>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x18fab1605c0>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x18fab1605f8>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x18fab160630>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x18fab160668>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x18fab1606a0>,
#  'remainder': <gensim.models.keyedvectors.Vocab at 0x18fab1606d8>,
#  'abnormal': <gensim.models.keyedvectors.Vocab at 0x18fab160710>,
#  'involves': <gensim.models.keyedvectors.Vocab at 0x18fab160748>,
#  'classifier': <gensim.models.keyedvectors.Vocab at 0x18fab160780>,
#  'inherent': <gensim.models.keyedvectors.Vocab at 0x18fab1607b8>,
#  'unbalanced': <gensim.models.keyedvectors.Vocab at 0x18fab1607f0>,
#  'construct': <gensim.models.keyedvectors.Vocab at 0x18fab160828>,
#  'representing': <gensim.models.keyedvectors.Vocab at 0x18fab160860>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x18fab160898>,
#  'likelihood': <gensim.models.keyedvectors.Vocab at 0x18fab1608d0>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x18fab160908>,
#  'generated': <gensim.models.keyedvectors.Vocab at 0x18fab160940>,
#  'trees': <gensim.models.keyedvectors.Vocab at 0x18fab160978>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x18fab1609b0>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x18fab1609e8>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x18fab160a20>,
#  'branches': <gensim.models.keyedvectors.Vocab at 0x18fab160a58>,
#  'conclusions': <gensim.models.keyedvectors.Vocab at 0x18fab160a90>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x18fab160ac8>,
#  'leaves': <gensim.models.keyedvectors.Vocab at 0x18fab160b00>,
#  'variable': <gensim.models.keyedvectors.Vocab at 0x18fab160b38>,
#  'discrete': <gensim.models.keyedvectors.Vocab at 0x18fab160b70>,
#  'structures': <gensim.models.keyedvectors.Vocab at 0x18fab160ba8>,
#  'conjunctions': <gensim.models.keyedvectors.Vocab at 0x18fab160be0>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x18fab160c18>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x18fab160c50>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x18fab160c88>,
#  'visually': <gensim.models.keyedvectors.Vocab at 0x18fab160cc0>,
#  'describes': <gensim.models.keyedvectors.Vocab at 0x18fab160cf8>,
#  'resulting': <gensim.models.keyedvectors.Vocab at 0x18fab160d30>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x18fab160d68>,
#  'rules': <gensim.models.keyedvectors.Vocab at 0x18fab160da0>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x18fab160dd8>,
#  'variables': <gensim.models.keyedvectors.Vocab at 0x18fab160e10>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x18fab160e48>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x18fab160e80>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x18fab160eb8>,
#  'interestingness': <gensim.models.keyedvectors.Vocab at 0x18fab160ef0>,
#  'generates': <gensim.models.keyedvectors.Vocab at 0x18fab160f28>,
#  'analyzes': <gensim.models.keyedvectors.Vocab at 0x18fab160f60>,
#  'ultimate': <gensim.models.keyedvectors.Vocab at 0x18fab160f98>,
#  'assuming': <gensim.models.keyedvectors.Vocab at 0x18fab160fd0>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x18fab164048>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x18fab164080>,
#  'mimic': <gensim.models.keyedvectors.Vocab at 0x18fab1640b8>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x18fab1640f0>,
#  'extraction': <gensim.models.keyedvectors.Vocab at 0x18fab164128>,
#  'capabilities': <gensim.models.keyedvectors.Vocab at 0x18fab164160>,
#  'evolves': <gensim.models.keyedvectors.Vocab at 0x18fab164198>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x18fab1641d0>,
#  'manipulate': <gensim.models.keyedvectors.Vocab at 0x18fab164208>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x18fab164240>,
#  'characteristic': <gensim.models.keyedvectors.Vocab at 0x18fab164278>,
#  'utilization': <gensim.models.keyedvectors.Vocab at 0x18fab1642b0>,
#  'relational': <gensim.models.keyedvectors.Vocab at 0x18fab1642e8>,
#  'collectively': <gensim.models.keyedvectors.Vocab at 0x18fab164320>,
#  'captured': <gensim.models.keyedvectors.Vocab at 0x18fab164358>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x18fab164390>,
#  'contrast': <gensim.models.keyedvectors.Vocab at 0x18fab1643c8>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x18fab164400>,
#  'singular': <gensim.models.keyedvectors.Vocab at 0x18fab164438>,
#  'universally': <gensim.models.keyedvectors.Vocab at 0x18fab164470>,
#  'immune': <gensim.models.keyedvectors.Vocab at 0x18fab1644a8>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x18fab1644e0>,
#  'rakesh': <gensim.models.keyedvectors.Vocab at 0x18fab164518>,
#  'agrawal': <gensim.models.keyedvectors.Vocab at 0x18fab164550>,
#  'tomasz': <gensim.models.keyedvectors.Vocab at 0x18fab164588>,
#  'imieli': <gensim.models.keyedvectors.Vocab at 0x18fab1645c0>,
#  'ski': <gensim.models.keyedvectors.Vocab at 0x18fab1645f8>,
#  'arun': <gensim.models.keyedvectors.Vocab at 0x18fab164630>,
#  'swami': <gensim.models.keyedvectors.Vocab at 0x18fab164668>,
#  'introduced': <gensim.models.keyedvectors.Vocab at 0x18fab1646a0>,
#  'regularities': <gensim.models.keyedvectors.Vocab at 0x18fab1646d8>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x18fab164710>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x18fab164748>,
#  'transaction': <gensim.models.keyedvectors.Vocab at 0x18fab164780>,
#  'recorded': <gensim.models.keyedvectors.Vocab at 0x18fab1647b8>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x18fab1647f0>,
#  'sale': <gensim.models.keyedvectors.Vocab at 0x18fab164828>,
#  'pos': <gensim.models.keyedvectors.Vocab at 0x18fab164860>,
#  'supermarkets': <gensim.models.keyedvectors.Vocab at 0x18fab164898>,
#  'o': <gensim.models.keyedvectors.Vocab at 0x18fab1648d0>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x18fab164908>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x18fab164940>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x18fab164978>,
#  'r': <gensim.models.keyedvectors.Vocab at 0x18fab1649b0>,
#  'g': <gensim.models.keyedvectors.Vocab at 0x18fab1649e8>,
#  'displaystyle': <gensim.models.keyedvectors.Vocab at 0x18fab164a20>,
#  'mathrm': <gensim.models.keyedvectors.Vocab at 0x18fab164a58>,
#  'onions': <gensim.models.keyedvectors.Vocab at 0x18fab164a90>,
#  'potatoes': <gensim.models.keyedvectors.Vocab at 0x18fab164ac8>,
#  'rightarrow': <gensim.models.keyedvectors.Vocab at 0x18fab164b00>,
#  'burger': <gensim.models.keyedvectors.Vocab at 0x18fab164b38>,
#  'sales': <gensim.models.keyedvectors.Vocab at 0x18fab164b70>,
#  'supermarket': <gensim.models.keyedvectors.Vocab at 0x18fab164ba8>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x18fab164be0>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x18fab164c18>,
#  'buys': <gensim.models.keyedvectors.Vocab at 0x18fab164c50>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x18fab164c88>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x18fab164cc0>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x18fab164cf8>,
#  'hamburger': <gensim.models.keyedvectors.Vocab at 0x18fab164d30>,
#  'meat': <gensim.models.keyedvectors.Vocab at 0x18fab164d68>,
#  'marketing': <gensim.models.keyedvectors.Vocab at 0x18fab164da0>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x18fab164dd8>,
#  'promotional': <gensim.models.keyedvectors.Vocab at 0x18fab164e10>,
#  'pricing': <gensim.models.keyedvectors.Vocab at 0x18fab164e48>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x18fab164e80>,
#  'placements': <gensim.models.keyedvectors.Vocab at 0x18fab164eb8>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x18fab164ef0>,
#  'basket': <gensim.models.keyedvectors.Vocab at 0x18fab164f28>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x18fab164f60>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x18fab164f98>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x18fab164fd0>,
#  'usage': <gensim.models.keyedvectors.Vocab at 0x18fab168048>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x18fab168080>,
#  'bioinformatics': <gensim.models.keyedvectors.Vocab at 0x18fab1680b8>,
#  'sequence': <gensim.models.keyedvectors.Vocab at 0x18fab1680f0>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x18fab168128>,
#  'transactions': <gensim.models.keyedvectors.Vocab at 0x18fab168160>,
#  'lcs': <gensim.models.keyedvectors.Vocab at 0x18fab168198>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x18fab1681d0>,
#  'combine': <gensim.models.keyedvectors.Vocab at 0x18fab168208>,
#  'seek': <gensim.models.keyedvectors.Vocab at 0x18fab168240>,
#  'dependent': <gensim.models.keyedvectors.Vocab at 0x18fab168278>,
#  'piecewise': <gensim.models.keyedvectors.Vocab at 0x18fab1682b0>,
#  'manner': <gensim.models.keyedvectors.Vocab at 0x18fab1682e8>,
#  ...}

# %% [markdown]
# ### Get an embedding for word `SVM`

# %%
model.wv['svm']
# Out:
# array([-0.42817754,  1.0493265 ,  0.33265767, -1.3082318 ,  1.1169025 ,
#         1.0030046 , -0.00340915,  0.6173608 , -0.96298313,  0.16009186,
#        -0.28315297, -0.3190175 , -0.01381337, -0.47134888,  0.42271686,
#        -0.40937755,  0.557296  ,  0.26535085,  0.4313733 , -0.66291076,
#        -0.1961258 , -1.2795964 , -1.133088  ,  0.6253178 , -0.49248698,
#         0.13017589, -1.2836212 , -0.7742435 , -0.69274795,  0.01466106,
#         0.044676  , -0.5969457 , -0.2654269 ,  1.8276255 , -0.61156255,
#         1.4701265 ,  0.19861451, -0.02155786, -0.6527102 ,  0.00305347,
#        -0.5848285 ,  1.1390697 , -0.21716228,  0.02662108, -0.2967651 ,
#        -0.5773036 ,  0.38282338,  0.10443805,  0.63126683,  0.4947669 ],
#       dtype=float32)

# %% [markdown]
# ### Finding most similar words for word `learning`

# %%
model.wv.most_similar('svm')
# Out:
# [('one', 0.9998096227645874),
#  ('an', 0.9997731447219849),
#  ('classification', 0.999770998954773),
#  ('other', 0.9997637271881104),
#  ('boosting', 0.9997509717941284),
#  ('techniques', 0.9997425675392151),
#  ('to', 0.9997419714927673),
#  ('many', 0.9997381567955017),
#  ('examples', 0.9997338652610779),
#  ('feature', 0.9997269511222839)]

# %% [markdown]
# ### Find the word which is not like others from `machine, svm, ball, learning`

# %%
model.doesnt_match("machine, svm, ball, learning".split())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `doesnt_match` (Method will be removed in 4.0.0, use self.wv.doesnt_match() instead).
#   """Entry point for launching an IPython kernel.
# 'learning'

# %% [markdown]
# ### Save the model with name `word2vec-wiki-10`

# %%
model.save('word2vec-wiki-10')

# %% [markdown]
# ### Load the model `word2vec-wiki-10`

# %%
model = gensim.models.Word2Vec.load('word2vec-wiki-10')
